# %%
from data_processing import *
from defined_functions import *
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
owl2vec_label,owl2vec_vector=load_owl2vec_embeddings(embedding_path,onto_path)

# %%
for i in owl2vec_label:
    owl2vec_vector.wv.get_vector(i.iri)

# %%
classes,model=load_owl2vec_embeddings(embedding_path,onto_path)
embedding_list=[]
for i in classes:
    model.wv.get_vector(i.iri)
    embedding_list.append(torch.tensor(model.wv.get_vector(i.iri)))
    
embedding_list=torch.stack(embedding_list)
embedding_list=embedding_list.to('cuda' if torch.cuda.is_available() else 'cpu')

# %%
classes
# Out:
# [obo.GO_0003674,
#  obo.GO_0005575,
#  obo.GO_0008150,
#  obo.GO_0000001,
#  obo.GO_0048308,
#  obo.GO_0048311,
#  obo.GO_0000002,
#  obo.GO_0000003,
#  obo.GO_0022414,
#  obo.GO_0000004,
#  obo.GO_0000005,
#  obo.GO_0042254,
#  obo.GO_0044183,
#  obo.GO_0051082,
#  obo.GO_0000006,
#  obo.GO_0005385,
#  obo.GO_0000007,
#  obo.GO_0000008,
#  obo.GO_0003756,
#  obo.GO_0015036,
#  obo.GO_0000009,
#  obo.GO_0000030,
#  obo.GO_0000010,
#  obo.GO_0120531,
#  obo.GO_0000011,
#  obo.GO_0007033,
#  obo.GO_0000012,
#  obo.GO_0006281,
#  obo.GO_0000013,
#  obo.GO_0000014,
#  obo.GO_0004520,
#  obo.GO_0016788,
#  obo.GO_0000015,
#  obo.GO_1902494,
#  obo.GO_0005829,
#  obo.GO_0000016,
#  obo.GO_0004553,
#  obo.GO_0000017,
#  obo.GO_0042946,
#  obo.GO_0000018,
#  obo.GO_0051052,
#  obo.GO_0006310,
#  obo.GO_0000019,
#  obo.GO_0006312,
#  obo.GO_0000020,
#  obo.GO_0045950,
#  obo.GO_0000021,
#  obo.GO_0007131,
#  obo.GO_0000022,
#  obo.GO_0051231,
#  obo.GO_1903047,
#  obo.GO_0000070,
# ...
